# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:\\Users\\sneha\\Downloads\\cars.csv")

# %%
data.head()
# Out:
#    Car_ID    Brand    Model  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0       1   Toyota  Corolla  2018              50000    Petrol       Manual
# 1       2    Honda    Civic  2019              40000    Petrol    Automatic
# 2       3     Ford  Mustang  2017              20000    Petrol    Automatic
# 3       4   Maruti    Swift  2020              30000    Diesel       Manual
# 4       5  Hyundai   Sonata  2016              60000    Diesel    Automatic
#
#   Owner_Type  Mileage  Engine  Power  Seats    Price
# 0      First       15    1498    108      5   800000
# 1     Second       17    1597    140      5  1000000
# 2      First       10    4951    395      4  2500000
# 3      Third       23    1248     74      5   600000
# 4     Second       18    1999    194      5   850000

# %%
data.isnull().sum()
# Out:
# Car_ID               0
# Brand                0
# Model                0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %%
data.nunique()
# Out:
# Car_ID               100
# Brand                 11
# Model                 58
# Year                   6
# Kilometers_Driven     18
# Fuel_Type              2
# Transmission           2
# Owner_Type             3
# Mileage               15
# Engine                36
# Power                 40
# Seats                  3
# Price                 31
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Car_ID             100 non-null    int64
#  1   Brand              100 non-null    object
#  2   Model              100 non-null    object
#  3   Year               100 non-null    int64
#  4   Kilometers_Driven  100 non-null    int64
#  5   Fuel_Type          100 non-null    object
#  6   Transmission       100 non-null    object
#  7   Owner_Type         100 non-null    object
#  8   Mileage            100 non-null    int64
#  9   Engine             100 non-null    int64
#  10  Power              100 non-null    int64
#  11  Seats              100 non-null    int64
#  12  Price              100 non-null    int64
# dtypes: int64(8), object(5)
# memory usage: 10.3+ KB

# %%
data.describe(include="all")
# Out:
#             Car_ID Brand    Model        Year  Kilometers_Driven Fuel_Type  \
# count   100.000000   100      100   100.00000         100.000000       100
# unique         NaN    11       58         NaN                NaN         2
# top            NaN  Ford  Mustang         NaN                NaN    Petrol
# freq           NaN    11        3         NaN                NaN        52
# mean     50.500000   NaN      NaN  2018.39000       28150.000000       NaN
# std      29.011492   NaN      NaN     1.17116        9121.375716       NaN
# min       1.000000   NaN      NaN  2016.00000       10000.000000       NaN
# 25%      25.750000   NaN      NaN  2017.75000       22000.000000       NaN
# 50%      50.500000   NaN      NaN  2018.00000       27000.000000       NaN
# 75%      75.250000   NaN      NaN  2019.00000       32000.000000       NaN
# max     100.000000   NaN      NaN  2021.00000       60000.000000       NaN
#
#        Transmission Owner_Type     Mileage       Engine       Power  \
# count           100        100  100.000000   100.000000  100.000000
# unique            2          3         NaN          NaN         NaN
# top       Automatic      First         NaN          NaN         NaN
# freq             57         44         NaN          NaN         NaN
# mean            NaN        NaN   17.210000  1855.230000  158.130000
# std             NaN        NaN    3.309902   631.311475   76.968137
# min             NaN        NaN   10.000000   999.000000   68.000000
# 25%             NaN        NaN   15.000000  1462.000000  103.000000
# 50%             NaN        NaN   17.000000  1774.000000  148.000000
# 75%             NaN        NaN   19.000000  2143.000000  187.000000
# max             NaN        NaN   25.000000  4951.000000  396.000000
#
#              Seats         Price
# count   100.000000  1.000000e+02
# unique         NaN           NaN
# top            NaN           NaN
# freq           NaN           NaN
# mean      5.230000  1.574000e+06
# std       0.750151  1.000265e+06
# min       4.000000  4.500000e+05
# 25%       5.000000  7.000000e+05
# 50%       5.000000  1.300000e+06
# 75%       5.000000  2.500000e+06
# max       7.000000  4.000000e+06

# %%
plt.figure(figure=(6,13))
sns.countplot(data=data,x="Brand")
plt.title("univariate analysis on brand")
plt.xticks(rotation=45)
plt.xlabel("Brand")
plt.ylabel("count")
plt.show()

# %%
transmission_counts=data["Transmission"].value_counts()
transmission_counts.plot(kind="pie",autopct="%1.1f%%",colors=['purple', 'violet', 'indigo', 'purple'],figsize=(5,5),title="Transmission Distribution")
plt.ylabel("")
plt.show()

# %%
Fuel_counts=data["Fuel_Type"].value_counts()
Fuel_counts.plot(kind="pie",autopct="%1.1f%%",colors=['purple', 'violet', 'indigo', 'purple'],figsize=(5,5),title="Fuel Type Distribution")
plt.ylabel("")
plt.show()

# %%
plt.figure(figure=(1,1))
sns.histplot(data["Power"],bins=20,kde=True)   #bins divide the data into intervals and kde is smooth curve line apppear on histogram
plt.title("Histogram for Power Distibution")
plt.xlabel("Power")
plt.ylabel("frequency")
plt.show()

# %%
plt.figure(figure=(6,13))
sns.countplot(data=data,x="Year")
plt.title("univariate analysis on Year")
plt.xlabel("Year")
plt.ylabel("count")
plt.show()

# %%
plt.figure(figsize=(10,12))
sns.violinplot(hue="Owner_Type", y= "Price",data=data,palette="muted")
plt.title("Price distribution by owner type")
plt.xlabel("Owner Type")
plt.ylabel("Price")
plt.show()

# %%
plt.figure(figure=(1,1))
sns.histplot(data["Kilometers_Driven"],bins=20,kde=True ,color="purple")   #bins divide the data into intervals and kde is smooth curve line apppear on histogram
plt.title("Histogram for Kilometers Driven Distibution")
plt.xlabel("Kilometers Driven")
plt.ylabel("frequency")
plt.show()

# %%
plt.figure(figure=(1,1))
sns.histplot(data["Mileage"],bins=20,kde=True,color="purple")   #bins divide the data into intervals and kde is smooth curve line apppear on histogram
plt.title("Histogram for Mileage Distibution")
plt.xlabel("Mileage")
plt.ylabel("frequency")
plt.show()

# %%
seats_counts=data["Seats"].value_counts()
seats_counts.plot(kind="pie",autopct="%1.1f%%",colors=['purple', 'violet', 'indigo', 'purple'],figsize=(5,5),title="Seats Distribution")
plt.ylabel("")
plt.show()

# %%
plt.figure(figure=(1,1))
sns.histplot(data["Price"],bins=20,kde=True)   #bins divide the data into intervals and kde is smooth curve line apppear on histogram
plt.title("Histogram for Price Distibution")
plt.xlabel("Price")
plt.ylabel("frequency")
plt.show()

# %%
data.head()
# Out:
#    Car_ID    Brand    Model  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0       1   Toyota  Corolla  2018              50000    Petrol       Manual
# 1       2    Honda    Civic  2019              40000    Petrol    Automatic
# 2       3     Ford  Mustang  2017              20000    Petrol    Automatic
# 3       4   Maruti    Swift  2020              30000    Diesel       Manual
# 4       5  Hyundai   Sonata  2016              60000    Diesel    Automatic
#
#   Owner_Type  Mileage  Engine  Power  Seats    Price
# 0      First       15    1498    108      5   800000
# 1     Second       17    1597    140      5  1000000
# 2      First       10    4951    395      4  2500000
# 3      Third       23    1248     74      5   600000
# 4     Second       18    1999    194      5   850000

# %%
plt.figure(figure=(20,4))
sns.countplot(x="Brand",hue="Transmission",data=data)
plt.title("Brand and Transmission")
plt.xlabel("Brand")
plt.xticks(rotation=45)
plt.ylabel("Transmission")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Kilometers_Driven', y='Price', data=data)
plt.title('Kilometers Driven vs Price')
plt.xlabel('Kilometers Driven')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Year', y='Price', data=data)
plt.title('Kilometers Driven vs Price')
plt.xlabel('Kilometers Driven')
plt.ylabel('Price')
plt.show()

# %%
contingency_table = pd.crosstab(data['Brand'], data['Fuel_Type'])
plt.figure(figsize=(8, 6))
sns.heatmap(contingency_table, annot=True, fmt='d', linewidths=0.5)
plt.title('Heatmap of Two Categorical Variables')
plt.show()

# %%
sns.kdeplot(data=data, x='Price', hue='Fuel_Type', fill=True)
plt.title('Conditional Kernel Density Estimate')
plt.xlabel("Price")
plt.ylabel("Density")
plt.show()

# %%
plt.figure(figsize=(10,12))
sns.violinplot(hue="Brand", y= "Price",data=data,palette="muted")
plt.title("Price distribution by brand")
plt.xlabel("Brand")
plt.ylabel("Price")
plt.show()

# %%
sns.barplot(x='Owner_Type', y='Brand', data=data, color='skyblue')
plt.title('Horizontal Bar Chart with Seaborn')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
categorical_columns=[ 'Brand', 'Model', 'Fuel_Type',
       'Transmission', 'Owner_Type' ]
le=LabelEncoder()
for col in categorical_columns:
    data[col]=le.fit_transform(data[col])

# %%
#creating correlation matrix
corr_mat=df.corr()
plt.figure(figsize=(11,8))
sns.heatmap(corr_mat,annot=True,cmap="coolwarm")
plt.title("correlation matrix")
plt.show()

# %%
from scipy.stats import f_oneway
cat_col = ["Brand","Model","Fuel_Type","Transmission","Owner_Type"]
for feature in cat_col:
    groups=[data[data[feature]==group]["Price"] for group in data[feature].unique()]
    f_stat,p_value=f_oneway(*groups)
    print(f"ANOVA results for {feature}:")
    print(f"F-statistics: {f_stat: 2f}")
    print(f"P-value: {p_value: 4f}")
# Out:
# ANOVA results for Brand:
# F-statistics:  28.230297
# P-value:  0.000000
# ANOVA results for Model:
# F-statistics:  272.960579
# P-value:  0.000000
# ANOVA results for Fuel_Type:
# F-statistics:  3.317942
# P-value:  0.071578
# ANOVA results for Transmission:
# F-statistics:  82.688441
# P-value:  0.000000
# ANOVA results for Owner_Type:
# F-statistics:  8.314449
# P-value:  0.000465

# %%
data.head()
# Out:
#    Brand  Model  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0      9     15           2.407540          1             1           0
# 1      3     14           1.305691          1             0           1
# 2      2     30          -0.898007          1             0           0
# 3      6     42           0.203842          0             1           2
# 4      4     41           3.509389          0             0           1
#
#     Mileage    Engine     Power     Seats    Price   Car_Age
# 0 -0.671057 -0.568704 -0.654590 -0.308149   800000  0.334681
# 1 -0.063766 -0.411098 -0.236739 -0.308149  1000000 -0.523475
# 2 -2.189286  4.928417  3.093011 -1.647929  2500000  1.192836
# 3  1.758109 -0.966700 -1.098556 -0.308149   600000 -1.381631
# 4  0.239880  0.228880  0.468385 -0.308149   850000  2.050992

# %%
data['Car_Age'] = 2024 - data['Year']

# %%
df.head()
# Out:
#    Brand  Model  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0      9     15           2.407540          1             1           0
# 1      3     14           1.305691          1             0           1
# 2      2     30          -0.898007          1             0           0
# 3      6     42           0.203842          0             1           2
# 4      4     41           3.509389          0             0           1
#
#     Mileage    Engine     Power     Seats    Price   Car_Age
# 0 -0.671057 -0.568704 -0.654590 -0.308149   800000  0.334681
# 1 -0.063766 -0.411098 -0.236739 -0.308149  1000000 -0.523475
# 2 -2.189286  4.928417  3.093011 -1.647929  2500000  1.192836
# 3  1.758109 -0.966700 -1.098556 -0.308149   600000 -1.381631
# 4  0.239880  0.228880  0.468385 -0.308149   850000  2.050992

# %%
data.head()
# Out:
#    Brand  Model  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0      9     15              50000          1             1           0
# 1      3     14              40000          1             0           1
# 2      2     30              20000          1             0           0
# 3      6     42              30000          0             1           2
# 4      4     41              60000          0             0           1
#
#    Mileage  Engine  Power  Seats    Price  Car_Age
# 0       15    1498    108      5   800000        6
# 1       17    1597    140      5  1000000        5
# 2       10    4951    395      4  2500000        7
# 3       23    1248     74      5   600000        4
# 4       18    1999    194      5   850000        8

# %%
#scaling
from sklearn.preprocessing import StandardScaler
numerical_features=["Kilometers_Driven","Mileage","Engine","Power","Seats" ,"Car_Age"]
scaler=StandardScaler()
data[numerical_features]=scaler.fit_transform(data[numerical_features])

# %%
data.head()
# Out:
#    Brand  Model  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0      9     15           2.407540          1             1           0
# 1      3     14           1.305691          1             0           1
# 2      2     30          -0.898007          1             0           0
# 3      6     42           0.203842          0             1           2
# 4      4     41           3.509389          0             0           1
#
#     Mileage    Engine     Power     Seats    Price   Car_Age
# 0 -0.671057 -0.568704 -0.654590 -0.308149   800000  0.334681
# 1 -0.063766 -0.411098 -0.236739 -0.308149  1000000 -0.523475
# 2 -2.189286  4.928417  3.093011 -1.647929  2500000  1.192836
# 3  1.758109 -0.966700 -1.098556 -0.308149   600000 -1.381631
# 4  0.239880  0.228880  0.468385 -0.308149   850000  2.050992

# %%
from sklearn.preprocessing import StandardScaler
numerical_features = ['Kilometers_Driven', 'Mileage', 'Engine', 'Power', 'Seats', 'Car_Age']
scaler = StandardScaler()
data[numerical_features] = scaler.fit_transform(data[numerical_features])

# %%
x=data.drop(columns=["Price"])
y=data["Price"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import numpy as np

# Model training
lrmodel = LinearRegression()
lrmodel.fit(x_train, y_train)

# Predictions
y_test_predlr = lrmodel.predict(x_test)  # For evaluating the test set
y_train_predlr = lrmodel.predict(x_train)

# Evaluation metrics
lr_metrics = {
    "test mean squared error": mean_squared_error(y_test, y_test_predlr),
    "test root mean squared error": np.sqrt(mean_squared_error(y_test, y_test_predlr)),
    "test mean absolute error": mean_absolute_error(y_test, y_test_predlr),
    "test r-squared": r2_score(y_test, y_test_predlr),
    "train mean squared error": mean_squared_error(y_train, y_train_predlr),
    "train root mean squared error": np.sqrt(mean_squared_error(y_train, y_train_predlr)),
    "train mean absolute error": mean_absolute_error(y_train, y_train_predlr),
    "train r-squared": r2_score(y_train, y_train_predlr)
}

# Print the metrics
print(lr_metrics)
# Out:
# {'test mean squared error': 218510222416.33218, 'test root mean squared error': 467450.77004571527, 'test mean absolute error': 367403.69163921924, 'test r-squared': 0.7328235955048821, 'train mean squared error': 139121508798.39056, 'train root mean squared error': 372989.9580396107, 'train mean absolute error': 287821.26851781196, 'train r-squared': 0.8587858743775416}

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import numpy as np

# Model training
mlrmodel = LinearRegression()
mlrmodel.fit(x_train, y_train)

# Predictions
y_test_predmlr = mlrmodel.predict(x_test)  # For evaluating the test set
y_train_predmlr = mlrmodel.predict(x_train)

# Evaluation metrics
mlr_metrics = {
    "test mean squared error": mean_squared_error(y_test, y_test_predmlr),
    "test root mean squared error": np.sqrt(mean_squared_error(y_test, y_test_predmlr)),
    "test mean absolute error": mean_absolute_error(y_test, y_test_predmlr),
    "test r-squared": r2_score(y_test, y_test_predmlr),
    "train mean squared error": mean_squared_error(y_train, y_train_predmlr),
    "train root mean squared error": np.sqrt(mean_squared_error(y_train, y_train_predmlr)),
    "train mean absolute error": mean_absolute_error(y_train, y_train_predmlr),
    "train r-squared": r2_score(y_train, y_train_predmlr)
}

# Print the metrics
print(mlr_metrics)
# Out:
# {'test mean squared error': 218510222416.33218, 'test root mean squared error': 467450.77004571527, 'test mean absolute error': 367403.69163921924, 'test r-squared': 0.7328235955048821, 'train mean squared error': 139121508798.39056, 'train root mean squared error': 372989.9580396107, 'train mean absolute error': 287821.26851781196, 'train r-squared': 0.8587858743775416}

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import numpy as np

# Model training
rfmodel = RandomForestRegressor()
rfmodel.fit(x_train, y_train)

# Predictions
y_test_predrf = rfmodel.predict(x_test)  # For evaluating the test set
y_train_predrf = rfmodel.predict(x_train)

# Evaluation metrics
rf_metrics = {
    "test mean squared error": mean_squared_error(y_test, y_test_predrf),
    "test root mean squared error": np.sqrt(mean_squared_error(y_test, y_test_predrf)),
    "test mean absolute error": mean_absolute_error(y_test, y_test_predrf),
    "test r-squared": r2_score(y_test, y_test_predrf),
    "train mean squared error": mean_squared_error(y_train, y_train_predrf),
    "train root mean squared error": np.sqrt(mean_squared_error(y_train, y_train_predrf)),
    "train mean absolute error": mean_absolute_error(y_train, y_train_predrf),
    "train r-squared": r2_score(y_train, y_train_predrf)
}

# Print the metrics
print(rf_metrics)
# Out:
# {'test mean squared error': 135781725000.0, 'test root mean squared error': 368485.71885488316, 'test mean absolute error': 196750.0, 'test r-squared': 0.8339772268753439, 'train mean squared error': 8686037500.0, 'train root mean squared error': 93198.91362027779, 'train mean absolute error': 57450.0, 'train r-squared': 0.9911833101776957}

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import numpy as np

# Model training
gbmodel = GradientBoostingRegressor()
gbmodel.fit(x_train, y_train)

# Predictions
y_test_predgb = gbmodel.predict(x_test)  # For evaluating the test set
y_train_predgb = gbmodel.predict(x_train)

# Evaluation metrics
gb_metrics = {
    "test mean squared error": mean_squared_error(y_test, y_test_predgb),
    "test root mean squared error": np.sqrt(mean_squared_error(y_test, y_test_predgb)),
    "test mean absolute error": mean_absolute_error(y_test, y_test_predgb),
    "test r-squared": r2_score(y_test, y_test_predgb),
    "train mean squared error": mean_squared_error(y_train, y_train_predgb),
    "train root mean squared error": np.sqrt(mean_squared_error(y_train, y_train_predgb)),
    "train mean absolute error": mean_absolute_error(y_train, y_train_predgb),
    "train r-squared": r2_score(y_train, y_train_predgb)
}

# Print the metrics
print(gb_metrics)
# Out:
# {'test mean squared error': 120633903599.13127, 'test root mean squared error': 347323.91740151047, 'test mean absolute error': 159675.49058264535, 'test r-squared': 0.8524987423132222, 'train mean squared error': 161901656.6776072, 'train root mean squared error': 12724.058184306106, 'train mean absolute error': 10359.991734844485, 'train r-squared': 0.9998356630755229}

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import numpy as np

# Model training
xgbmodel = XGBRegressor()
xgbmodel.fit(x_train, y_train)

# Predictions
y_test_predxgb = xgbmodel.predict(x_test)  # For evaluating the test set
y_train_predxgb = xgbmodel.predict(x_train)

# Evaluation metrics
xgb_metrics = {
    "test mean squared error": mean_squared_error(y_test, y_test_predxgb),
    "test root mean squared error": np.sqrt(mean_squared_error(y_test, y_test_predxgb)),
    "test mean absolute error": mean_absolute_error(y_test, y_test_predxgb),
    "test r-squared": r2_score(y_test, y_test_predxgb),
    "train mean squared error": mean_squared_error(y_train, y_train_predxgb),
    "train root mean squared error": np.sqrt(mean_squared_error(y_train, y_train_predxgb)),
    "train mean absolute error": mean_absolute_error(y_train, y_train_predxgb),
    "train r-squared": r2_score(y_train, y_train_predxgb)
}

# Print the metrics
print(xgb_metrics)
# Out:
# {'test mean squared error': 87379929987.96802, 'test root mean squared error': 295600.96411880665, 'test mean absolute error': 146846.3953125, 'test r-squared': 0.8931589778223782, 'train mean squared error': 0.16614990234375, 'train root mean squared error': 0.40761489465394907, 'train mean absolute error': 0.312109375, 'train r-squared': 0.9999999999998314}

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import numpy as np

# Model training
dtmodel = DecisionTreeRegressor()
dtmodel.fit(x_train, y_train)

# Predictions
y_test_preddt = dtmodel.predict(x_test)  # For evaluating the test set
y_train_preddt = dtmodel.predict(x_train)

# Evaluation metrics
dt_metrics = {
    "test mean squared error": mean_squared_error(y_test, y_test_preddt),
    "test root mean squared error": np.sqrt(mean_squared_error(y_test, y_test_preddt)),
    "test mean absolute error": mean_absolute_error(y_test, y_test_preddt),
    "test r-squared": r2_score(y_test, y_test_preddt),
    "train mean squared error": mean_squared_error(y_train, y_train_preddt),
    "train root mean squared error": np.sqrt(mean_squared_error(y_train, y_train_preddt)),
    "train mean absolute error": mean_absolute_error(y_train, y_train_preddt),
    "train r-squared": r2_score(y_train, y_train_preddt)
}

# Print the metrics
print(dt_metrics)
# Out:
# {'test mean squared error': 196250000000.0, 'test root mean squared error': 443001.12866673374, 'test mean absolute error': 220000.0, 'test r-squared': 0.7600415724154796, 'train mean squared error': 0.0, 'train root mean squared error': 0.0, 'train mean absolute error': 0.0, 'train r-squared': 1.0}

# %%
from scipy.stats import skew, kurtosis 
for column in ['Price', 'Kilometers_Driven', 'Mileage', 'Engine', 'Power']:
    print(f"{column}: Skewness={skew(df[column])}, Kurtosis={kurtosis(data[column])}")
# Out:
# Price: Skewness=0.6050329812494293, Kurtosis=-0.9538555671076092
# Kilometers_Driven: Skewness=0.6119028972373495, Kurtosis=0.5923528930215918
# Mileage: Skewness=0.3669713346017753, Kurtosis=-0.10892284732938684
# Engine: Skewness=1.5293251242735937, Kurtosis=4.3242695833017315
# Power: Skewness=1.4116898837107796, Kurtosis=1.8147746369059359

# %%
from scipy.stats import zscore
z_scores = data[['Price', 'Kilometers_Driven', 'Mileage', 'Engine', 'Power']].apply(zscore)
outliers = (z_scores.abs() > 3).any(axis=1)
print(f"Number of Outliers: {outliers.sum()}")
# Out:
# Number of Outliers: 4

# %%
coefficients = pd.DataFrame({
    'Feature': x_train.columns,
    'Coefficient': mlrmodel.coef_
})
print(coefficients.sort_values(by='Coefficient', ascending=False))
# Out:
#               Feature    Coefficient
# 8               Power  613673.652435
# 10            Car_Age   75468.208933
# 9               Seats   56847.237636
# 1               Model   -5762.387259
# 0               Brand  -25801.653704
# 5          Owner_Type  -54596.385477
# 7              Engine  -96787.092278
# 6             Mileage -103566.888672
# 2   Kilometers_Driven -133844.512588
# 3           Fuel_Type -468033.044728
# 4        Transmission -531671.386627

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor
xgb_model = XGBRegressor(random_state=42)
param_grid = {
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [3, 5, 7],
    'n_estimators': [100, 200, 300],
    'subsample': [0.8, 0.9, 1.0],
    'colsample_bytree': [0.8, 0.9, 1.0],
    'min_child_weight': [1, 3, 5]
}

grid_search = GridSearchCV(
    estimator=xgb_model,
    param_grid=param_grid,
    cv=3,  # 3-fold cross-validation
    scoring='neg_mean_squared_error',  # Evaluation metric
    verbose=2,
    n_jobs=-1
)

grid_search.fit(x_train, y_train)

print("Best parameters:", grid_search.best_params_)
# Out:
# Fitting 3 folds for each of 729 candidates, totalling 2187 fits
# Best parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 7, 'min_child_weight': 3, 'n_estimators': 100, 'subsample': 0.8}

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor

# Initializing the XGBoost model
xgb_model = XGBRegressor(random_state=42)

# Defining the parameter grid
param_grid = {
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [3, 5, 7],
    'n_estimators': [100, 200, 300],
    'subsample': [0.8, 0.9, 1.0],
    'colsample_bytree': [0.8, 0.9, 1.0],
    'min_child_weight': [1, 3, 5]
}

grid_search = GridSearchCV(
    estimator=xgb_model,
    param_grid=param_grid,
    cv=3,  # 3-fold cross-validation
    scoring='neg_mean_squared_error',  # Evaluation metric
    verbose=2,
    n_jobs=-1
)

# Fitting GridSearchCV
grid_search.fit(x_train, y_train)

# Displaying the best parameters
print("Best parameters:", grid_search.best_params_)
# Out:
# Fitting 3 folds for each of 729 candidates, totalling 2187 fits
# Best parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 7, 'min_child_weight': 3, 'n_estimators': 100, 'subsample': 0.8}

# %%
from sklearn.model_selection import RandomizedSearchCV
import numpy as np

# Defining the parameter distribution
param_dist = {
    'learning_rate': np.linspace(0.01, 0.2, 10),
    'max_depth': [3, 5, 7, 9],
    'n_estimators': [100, 200, 300, 500],
    'subsample': np.linspace(0.7, 1.0, 4),
    'colsample_bytree': np.linspace(0.7, 1.0, 4),
    'min_child_weight': [1, 3, 5, 7]
}

# Performing RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=xgb_model,
    param_distributions=param_dist,
    n_iter=50,  # Number of parameter combinations to try
    cv=3,  # 3-fold cross-validation
    scoring='neg_mean_squared_error',
    verbose=2,
    random_state=42,
    n_jobs=-1
)

# Fitting RandomizedSearchCV
random_search.fit(x_train, y_train)

# Displaying the best parameters
print("Best parameters:", random_search.best_params_)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# Best parameters: {'subsample': 0.7999999999999999, 'n_estimators': 200, 'min_child_weight': 5, 'max_depth': 3, 'learning_rate': 0.1577777777777778, 'colsample_bytree': 0.9}

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Training the GridSearchCV model
xgb_grid_model = XGBRegressor(
    colsample_bytree=0.8, 
    learning_rate=0.05, 
    max_depth=7, 
    min_child_weight=3, 
    n_estimators=100, 
    subsample=0.8, 
    random_state=42
)
xgb_grid_model.fit(x_train, y_train)

# Training the RandomizedSearchCV model
xgb_random_model = XGBRegressor(
    colsample_bytree=0.9, 
    learning_rate=0.1578, 
    max_depth=3, 
    min_child_weight=5, 
    n_estimators=200, 
    subsample=0.8, 
    random_state=42
)
xgb_random_model.fit(x_train, y_train)

# Evaluating both models on the test set
for model, name in zip([xgb_grid_model, xgb_random_model], ["GridSearchCV", "RandomizedSearchCV"]):
    y_test_pred = model.predict(x_test)
    mae = mean_absolute_error(y_test, y_test_pred)
    mse = mean_squared_error(y_test, y_test_pred)
    r2 = r2_score(y_test, y_test_pred)
    print(f"{name} Model - MAE: {mae}, MSE: {mse}, R²: {r2}")
# Out:
# GridSearchCV Model - MAE: 172250.2765625, MSE: 93483575883.68423, R²: 0.8856959394954035
# RandomizedSearchCV Model - MAE: 139089.5125, MSE: 81426867517.06436, R²: 0.9004378950699219

# %%
import matplotlib.pyplot as plt
from xgboost import plot_importance

plot_importance(xgb_random_model)
plt.show()

# %%
residuals = y_test - xgb_random_model.predict(x_test)
plt.hist(residuals, bins=20)
plt.title("Residual Distribution")
plt.show()

# %%
pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.46.0-cp312-cp312-win_amd64.whl.metadata (25 kB)
# Requirement already satisfied: numpy in c:\users\sneha\anaconda3\lib\site-packages (from shap) (1.26.4)
# Requirement already satisfied: scipy in c:\users\sneha\anaconda3\lib\site-packages (from shap) (1.13.1)
# Requirement already satisfied: scikit-learn in c:\users\sneha\anaconda3\lib\site-packages (from shap) (1.4.2)
# Requirement already satisfied: pandas in c:\users\sneha\anaconda3\lib\site-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\sneha\anaconda3\lib\site-packages (from shap) (4.66.4)
# Requirement already satisfied: packaging>20.9 in c:\users\sneha\anaconda3\lib\site-packages (from shap) (23.2)
# Collecting slicer==0.0.8 (from shap)
#   Downloading slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: numba in c:\users\sneha\anaconda3\lib\site-packages (from shap) (0.59.1)
# Requirement already satisfied: cloudpickle in c:\users\sneha\anaconda3\lib\site-packages (from shap) (2.2.1)
# Requirement already satisfied: colorama in c:\users\sneha\anaconda3\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\sneha\anaconda3\lib\site-packages (from numba->shap) (0.42.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sneha\anaconda3\lib\site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sneha\anaconda3\lib\site-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sneha\anaconda3\lib\site-packages (from pandas->shap) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\sneha\anaconda3\lib\site-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sneha\anaconda3\lib\site-packages (from scikit-learn->shap) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\sneha\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)
# Downloading shap-0.46.0-cp312-cp312-win_amd64.whl (456 kB)
#    ---------------------------------------- 0.0/456.2 kB ? eta -:--:--
#    --- ------------------------------------ 41.0/456.2 kB ? eta -:--:--
#    --- ------------------------------------ 41.0/456.2 kB ? eta -:--:--
#    --- ------------------------------------ 41.0/456.2 kB ? eta -:--:--
#    --- ------------------------------------ 41.0/456.2 kB ? eta -:--:--
#    --------- ---------------------------- 112.6/456.2 kB 502.0 kB/s eta 0:00:01
#    ----------- -------------------------- 143.4/456.2 kB 472.1 kB/s eta 0:00:01
#    ---------------- --------------------- 194.6/456.2 kB 560.2 kB/s eta 0:00:01
#    --------------------- ---------------- 256.0/456.2 kB 628.5 kB/s eta 0:00:01
#    ---------------------------- --------- 337.9/456.2 kB 776.5 kB/s eta 0:00:01
#    -------------------------------------  450.6/456.2 kB 938.8 kB/s eta 0:00:01
#    -------------------------------------- 456.2/456.2 kB 892.0 kB/s eta 0:00:00
# Downloading slicer-0.0.8-py3-none-any.whl (15 kB)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.46.0 slicer-0.0.8
# Note: you may need to restart the kernel to use updated packages.

# %%
import shap

explainer = shap.Explainer(xgb_random_model, x_test)
shap_values = explainer(x_test)

# Summary Plot
shap.summary_plot(shap_values, x_test)

# %%
import pickle

# Saving the trained model to a file
with open("secondhandcarpriceprediction.pkl", "wb") as f:
    pickle.dump(xgb_random_model, f)
